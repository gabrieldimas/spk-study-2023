# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrieldimas/spk-study-2023/blob/main/SPK_Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # JOBSHEET MATA KULIAH SISTEM PENDUKUNG KEPUTUSAN
#  Weighted Sum Model (WSM) dan Weighted Product Model (WPM)

# %% [markdown]
# PROSEDUR PRAKTIKUM

# %% [markdown]
# 1. Kelompokkanlah kriteria-kriteria yang termasuk dalam benefit attribut dan cost attribut!
# *   Benefit :
#   1.   Fasilitas Pendukung
#   2.   Tahun konstruksi bangunan
#   3. Sistem keamanan apartemen
#
# *   Cost :
#   1.   Harga bangunan
#   2.   Jarak dari tempat kerja
#
#
# 2. Buatlah perhitungan skor akhir dari tiap alternatif dengan menggunakan Excel sehingga menjadi semi-otomatis dan tentukan alternatif terbaik untuk kasus tersebut!
# *   WSM
#
#   ![image.png](data:image/png;base64,...)
# *   WPM
#
#     ![image.png](data:image/png;base64,...)
#
#     ![image.png](data:image/png;base64,...)
#
# 3. Bonus! Buatlah kode program untuk studi kasus. Anda dapat menggunakan bahasa
# pemograman sesuai dengan keahlian Anda

# %% [markdown]
# Pertanyaan

# %% [markdown]
# Ubahlah skor pada kriteria c1 dan c2 seperti berikut ini:
#
# *   Apartemen 2: c1 = 2
# *   Apartemen 1: c2 = 8. 500.000
#
# Amati perubahan skor akhir dari perhitungan WSM dan WPM pada alternatif 1 dan 2
# sebelum dan sesudah dilakukan perubahan skor kriteria tersebut.
#
#   ![image.png](data:image/png;base64,...)
#
#   ![image.png](data:image/png;base64,...)
#
#
# Dari hasil pengamatan,
# jelaskanlah:
# 1. Pengaruh perubahan skor kriteria bagi hasil pengambilan keputusan.
# 2. Perbedaan dari benefit attribut dan cost attribut
#
# Jawaban :
# 1. Pada metode WSM, tidak ada pengaruh yang terjadi. Sedangkan pada metode WSM terjadi perubahan urutan alternatif dari yang awalnya A1 dan A3 ada pada peringkat 1 dan A2 ada pada peringkat 2, menjadi A2, A3, dan A1
# 2.
# *   Benefit : Atribut yang dimaksimalkan. Skor berbanding lurus dengan nilai
# *   Cost : Atribut yang diminimalkan. Skor berbanding terbalik dengan nilai
